# %%
import googleapiclient.discovery
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
from IPython.display import JSON

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\velic\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\velic\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
api_key = 'AIzaSyCJRkHBXfzKnQUaRDK2FtQ5i9WlnAqmxQc'

# %%
channel_ids = ['UC8butISFwT-Wl7EV0hUK0BQ']

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    """
    Get channel stats
    
    Params:
    ------
    youtube: build object of Youtube API
    channel_ids: list of channel IDs
    
    Returns:
    ------
    dataframe with all channel stats for each channel ID
    
    """
    
    all_data = []
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()
   
      #loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'], 
                'views': item['statistics']['viewCount'],
                'totalViews': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        all_data.append(data)
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#         channelName subscribers      views totalViews  \
# 0  freeCodeCamp.org     8070000  572392940       1474
#
#                  playlistId
# 0  UU8butISFwT-Wl7EV0hUK0BQ

# %%
def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId = playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId = playlist_id,
                maxResults = 50,
                pageToken = next_page_token)
        response = request.execute()
        
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
        next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
#Get the qwuantity of videos in each channel
all_video_ids = []

for ind in channel_stats.index:
    video_ids = get_video_ids(youtube, channel_stats['playlistId'][ind])
    print(len(video_ids))
    all_video_ids.extend(video_ids)
# Out:
# 1475

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id=','.join(video_ids[i:i+50])
        )
        response = request.execute()
        
       # if i==0:
       #     print(response['items'][0])
        
        for video in response['items']:
            stats_to_keep = {'snippet': ['channelId', 'channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                        'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                        'contentDetails': ['duration', 'definition', 'caption']
                        }
            video_info = {}
            video_info['video_id'] = video['id']
            
     
         #   video_info['channelTitle']=video['snippet']['channelTitle']
         #  video_info['title']=video['snippet']['title']
         #   video_info['description']=video['snippet']['description']
         #   video_info['tags']=video['snippet']['tags']
        
            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                         video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
        
    return pd.DataFrame(all_video_info)

# %%
# Get video details
video_df = get_video_details(youtube, all_video_ids)
video_df
# Out:
#          video_id                 channelId      channelTitle  \
# 0     FJAO6jDYljs  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1     ETV17M4SauU  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 2     8M3YqhO3kVs  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 3     QdxUZhLHZiA  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 4     0tM-l_ZsxjU  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# ...           ...                       ...               ...
# 1470  _uWzpyr_5qk  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1471  xXLj5MbrI44  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1472  veugT7A9psY  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1473  xj9mFD71Vfc  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1474  q7tlgZg4Q1o  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
#
#                                                   title  \
# 0     Project-Based Augmented Reality Course with Un...
# 1     Next.js & Appwrite – Full Stack Course for Beg...
# 2                                       Favicon in HTML
# 3     Full Stack Next.js & Supabase Twitter Clone – ...
# 4     Python Tkinter GUI Design Using ttkbootstrap -...
# ...                                                 ...
# 1470        Computer Basics 5: How To Measure Data Size
# 1471        Computer Basics 4: Decoding a Binary Number
# 1472            Computer Basics 3: Intro to Binary Code
# 1473          Computer Basics 2: More Computer Hardware
# 1474  Computer Basics 1: The 4 Basic Parts of a Comp...
#
#                                             description  \
# 0     Learn Augmented Reality development in this fu...
# 1     Learn Next.js by building a custom API with Mo...
# 2     Learn more about HTML: https://www.youtube.com...
# 3     Learn Full Stack development with Next.js 13, ...
# 4     Learn how to easily implement modern designs i...
# ...                                                 ...
# 1470  http://FreeCodeCamp.com is a community of busy...
# 1471  http://FreeCodeCamp.com is a community of busy...
# 1472  http://FreeCodeCamp.com is a community of busy...
# 1473  http://FreeCodeCamp.com is a community of busy...
# 1474  http://FreeCodeCamp.com is a community of busy...
#
#                                                    tags           publishedAt  \
# 0                                                  None  2023-07-27T12:53:33Z
# 1                                                  None  2023-07-26T14:03:18Z
# 2                                                  None  2023-07-21T17:03:56Z
# 3                                                  None  2023-07-20T14:55:49Z
# 4                                                  None  2023-07-18T14:09:39Z
# ...                                                 ...                   ...
# 1470  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:23Z
# 1471  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:20Z
# 1472  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:17Z
# 1473  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:14Z
# 1474  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:10Z
#
#      viewCount likeCount favouriteCount commentCount    duration definition  \
# 0        23123       851           None           40   PT2H2M24S         hd
# 1        40849      1703           None           79  PT5H55M17S         hd
# 2        35836      2028           None           19       PT52S         hd
# 3        60068      2239           None          131   PT6H15M9S         hd
# 4        40698      1233           None           70  PT3H23M58S         hd
# ...        ...       ...            ...          ...         ...        ...
# 1470     49786      None           None           33     PT2M24S         hd
# 1471     64841      None           None           36     PT1M42S         hd
# 1472     55071      None           None           12        PT1M         hd
# 1473     63770      None           None           16     PT1M12S         hd
# 1474    147265      None           None           69      PT1M4S         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 1470   false
# 1471    true
# 1472    true
# 1473    true
# 1474    true
#
# [1475 rows x 14 columns]

# %%
# Check for NULL values
video_df.isnull().any()
# Out:
# video_id          False
# channelId         False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount          True
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
# Check data types
video_df.dtypes
# Out:
# video_id          object
# channelId         object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# Convert count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
# Publish day in the week
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['publishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs', 'duration']]
# Out:
#       durationSecs    duration
# 0           7344.0   PT2H2M24S
# 1          21317.0  PT5H55M17S
# 2             52.0       PT52S
# 3          22509.0   PT6H15M9S
# 4          12238.0  PT3H23M58S
# ...            ...         ...
# 1470         144.0     PT2M24S
# 1471         102.0     PT1M42S
# 1472          60.0        PT1M
# 1473          72.0     PT1M12S
# 1474          64.0      PT1M4S
#
# [1475 rows x 2 columns]

# %%
video_df
# Out:
#          video_id                 channelId      channelTitle  \
# 0     FJAO6jDYljs  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1     ETV17M4SauU  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 2     8M3YqhO3kVs  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 3     QdxUZhLHZiA  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 4     0tM-l_ZsxjU  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# ...           ...                       ...               ...
# 1470  _uWzpyr_5qk  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1471  xXLj5MbrI44  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1472  veugT7A9psY  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1473  xj9mFD71Vfc  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
# 1474  q7tlgZg4Q1o  UC8butISFwT-Wl7EV0hUK0BQ  freeCodeCamp.org
#
#                                                   title  \
# 0     Project-Based Augmented Reality Course with Un...
# 1     Next.js & Appwrite – Full Stack Course for Beg...
# 2                                       Favicon in HTML
# 3     Full Stack Next.js & Supabase Twitter Clone – ...
# 4     Python Tkinter GUI Design Using ttkbootstrap -...
# ...                                                 ...
# 1470        Computer Basics 5: How To Measure Data Size
# 1471        Computer Basics 4: Decoding a Binary Number
# 1472            Computer Basics 3: Intro to Binary Code
# 1473          Computer Basics 2: More Computer Hardware
# 1474  Computer Basics 1: The 4 Basic Parts of a Comp...
#
#                                             description  \
# 0     Learn Augmented Reality development in this fu...
# 1     Learn Next.js by building a custom API with Mo...
# 2     Learn more about HTML: https://www.youtube.com...
# 3     Learn Full Stack development with Next.js 13, ...
# 4     Learn how to easily implement modern designs i...
# ...                                                 ...
# 1470  http://FreeCodeCamp.com is a community of busy...
# 1471  http://FreeCodeCamp.com is a community of busy...
# 1472  http://FreeCodeCamp.com is a community of busy...
# 1473  http://FreeCodeCamp.com is a community of busy...
# 1474  http://FreeCodeCamp.com is a community of busy...
#
#                                                    tags           publishedAt  \
# 0                                                  None  2023-07-27T12:53:33Z
# 1                                                  None  2023-07-26T14:03:18Z
# 2                                                  None  2023-07-21T17:03:56Z
# 3                                                  None  2023-07-20T14:55:49Z
# 4                                                  None  2023-07-18T14:09:39Z
# ...                                                 ...                   ...
# 1470  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:23Z
# 1471  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:20Z
# 1472  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:17Z
# 1473  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:14Z
# 1474  [Free Code Camp, JavaScript, Pair Programming,...  2015-07-17T08:31:10Z
#
#       viewCount  likeCount  favouriteCount  commentCount    duration  \
# 0       23123.0      851.0             NaN          40.0   PT2H2M24S
# 1       40849.0     1703.0             NaN          79.0  PT5H55M17S
# 2       35836.0     2028.0             NaN          19.0       PT52S
# 3       60068.0     2239.0             NaN         131.0   PT6H15M9S
# 4       40698.0     1233.0             NaN          70.0  PT3H23M58S
# ...         ...        ...             ...           ...         ...
# 1470    49786.0        NaN             NaN          33.0     PT2M24S
# 1471    64841.0        NaN             NaN          36.0     PT1M42S
# 1472    55071.0        NaN             NaN          12.0        PT1M
# 1473    63770.0        NaN             NaN          16.0     PT1M12S
# 1474   147265.0        NaN             NaN          69.0      PT1M4S
#
#      definition caption  durationSecs
# 0            hd   false        7344.0
# 1            hd   false       21317.0
# 2            hd   false          52.0
# 3            hd   false       22509.0
# 4            hd   false       12238.0
# ...         ...     ...           ...
# 1470         hd   false         144.0
# 1471         hd    true         102.0
# 1472         hd    true          60.0
# 1473         hd    true          72.0
# 1474         hd    true          64.0
#
# [1475 rows x 15 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## Best performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### Worst performing videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ### View distribution per video

# %%
sns.violinplot(video_df['channelTitle'], video_df['viewCount'])
# Out:
# C:\Users\velic\programs\python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# ### Views vs. likes and comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ### Video duration

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# ### Upload schedule

# %%
day_df = pd.DataFrame(video_df['publishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='publishDayName', rot=0)
